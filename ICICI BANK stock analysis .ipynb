# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df=pd.read_csv('ICICIBANK.csv')

# %%
df
# Out:
#             Date     Symbol Series  Prev Close    Open    High     Low  \
# 0     2000-01-03  ICICIBANK     EQ       69.20   74.35   74.75   71.40
# 1     2000-01-04  ICICIBANK     EQ       74.75   73.05   78.50   71.00
# 2     2000-01-05  ICICIBANK     EQ       73.05   70.00   73.50   67.50
# 3     2000-01-06  ICICIBANK     EQ       69.50   71.00   74.00   69.55
# 4     2000-01-07  ICICIBANK     EQ       70.05   69.00   72.50   66.00
# ...          ...        ...    ...         ...     ...     ...     ...
# 5301  2021-04-26  ICICIBANK     EQ      569.95  602.00  605.50  588.00
# 5302  2021-04-27  ICICIBANK     EQ      591.10  593.25  601.95  591.10
# 5303  2021-04-28  ICICIBANK     EQ      598.75  598.00  622.80  598.00
# 5304  2021-04-29  ICICIBANK     EQ      621.35  622.55  628.45  609.00
# 5305  2021-04-30  ICICIBANK     EQ      621.45  610.10  616.35  598.10
#
#         Last   Close    VWAP    Volume      Turnover    Trades  \
# 0      74.75   74.75   73.20    286260  2.095439e+12       NaN
# 1      73.25   73.05   73.38    296264  2.173893e+12       NaN
# 2      70.00   69.50   70.85    227624  1.612794e+12       NaN
# 3      69.75   70.05   72.04    275149  1.982121e+12       NaN
# 4      67.00   67.40   68.72    138809  9.538882e+11       NaN
# ...      ...     ...     ...       ...           ...       ...
# 5301  588.70  591.10  596.22  62584522  3.731429e+15  546696.0
# 5302  599.00  598.75  597.63  24239685  1.448630e+15  233412.0
# 5303  619.70  621.35  612.57  33292864  2.039422e+15  295406.0
# 5304  621.00  621.45  619.55  34537860  2.139792e+15  304029.0
# 5305  599.70  600.50  607.02  23653258  1.435801e+15  247055.0
#
#       Deliverable Volume  %Deliverble
# 0                    NaN          NaN
# 1                    NaN          NaN
# 2                    NaN          NaN
# 3                    NaN          NaN
# 4                    NaN          NaN
# ...                  ...          ...
# 5301          16913351.0       0.2702
# 5302           9056247.0       0.3736
# 5303          14011476.0       0.4209
# 5304          10324897.0       0.2989
# 5305           7292392.0       0.3083
#
# [5306 rows x 15 columns]

# %%
df.head()
# Out:
#          Date     Symbol Series  Prev Close   Open   High    Low   Last  \
# 0  2000-01-03  ICICIBANK     EQ       69.20  74.35  74.75  71.40  74.75
# 1  2000-01-04  ICICIBANK     EQ       74.75  73.05  78.50  71.00  73.25
# 2  2000-01-05  ICICIBANK     EQ       73.05  70.00  73.50  67.50  70.00
# 3  2000-01-06  ICICIBANK     EQ       69.50  71.00  74.00  69.55  69.75
# 4  2000-01-07  ICICIBANK     EQ       70.05  69.00  72.50  66.00  67.00
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  74.75  73.20  286260  2.095439e+12     NaN                 NaN          NaN
# 1  73.05  73.38  296264  2.173893e+12     NaN                 NaN          NaN
# 2  69.50  70.85  227624  1.612794e+12     NaN                 NaN          NaN
# 3  70.05  72.04  275149  1.982121e+12     NaN                 NaN          NaN
# 4  67.40  68.72  138809  9.538882e+11     NaN                 NaN          NaN

# %%
df.tail()
# Out:
#             Date     Symbol Series  Prev Close    Open    High    Low   Last  \
# 5301  2021-04-26  ICICIBANK     EQ      569.95  602.00  605.50  588.0  588.7
# 5302  2021-04-27  ICICIBANK     EQ      591.10  593.25  601.95  591.1  599.0
# 5303  2021-04-28  ICICIBANK     EQ      598.75  598.00  622.80  598.0  619.7
# 5304  2021-04-29  ICICIBANK     EQ      621.35  622.55  628.45  609.0  621.0
# 5305  2021-04-30  ICICIBANK     EQ      621.45  610.10  616.35  598.1  599.7
#
#        Close    VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 5301  591.10  596.22  62584522  3.731429e+15  546696.0          16913351.0
# 5302  598.75  597.63  24239685  1.448630e+15  233412.0           9056247.0
# 5303  621.35  612.57  33292864  2.039422e+15  295406.0          14011476.0
# 5304  621.45  619.55  34537860  2.139792e+15  304029.0          10324897.0
# 5305  600.50  607.02  23653258  1.435801e+15  247055.0           7292392.0
#
#       %Deliverble
# 5301       0.2702
# 5302       0.3736
# 5303       0.4209
# 5304       0.2989
# 5305       0.3083

# %%
df.size
# Out:
# 79590

# %%
df.shape
# Out:
# (5306, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4789 non-null   float64
#  14  %Deliverble         4789 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 621.9+ KB

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean    550.895392   551.558538   560.558556   541.534197   551.050980
# std     368.784064   368.890953   374.079697   363.389664   368.705647
# min      67.400000    67.000000    70.450000    66.000000    67.000000
# 25%     267.562500   267.400000   271.912500   263.625000   267.400000
# 50%     398.075000   399.000000   406.525000   392.450000   398.700000
# 75%     873.562500   877.000000   888.775000   859.800000   874.600000
# max    1794.100000  1767.050000  1798.150000  1760.150000  1793.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03    2456.000000
# mean    550.995524   551.129031  8.224631e+06  3.759336e+14  138367.627443
# std     368.725374   368.746905  1.218535e+07  4.759238e+14   99008.729009
# min      67.400000    68.520000  7.409000e+03  9.617283e+10    2595.000000
# 25%     267.612500   267.577500  9.612055e+05  3.459444e+13   79312.250000
# 50%     398.175000   398.235000  3.486648e+06  2.923010e+14  110101.000000
# 75%     873.562500   873.510000  1.157202e+07  4.993528e+14  162953.500000
# max    1794.100000  1783.460000  2.868577e+08  1.461959e+16  949891.000000
#
#        Deliverable Volume  %Deliverble
# count        4.789000e+03  4789.000000
# mean         4.183406e+06     0.473463
# std          6.365382e+06     0.131495
# min          1.501500e+04     0.099000
# 25%          6.995020e+05     0.384300
# 50%          1.963117e+06     0.476400
# 75%          5.948817e+06     0.564100
# max          2.325307e+08     0.983000

# %%
df.isna().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     517
# %Deliverble            517
# dtype: int64

# %%
deliv_vol_null = df[df['Deliverable Volume'].isnull()]
deliv_pct_null = df[df['%Deliverble'].isnull()]

print("Number of null values in Deliverable Volume:", len(deliv_vol_null))
print("Number of null values in %Deliverble:", len(deliv_pct_null))
print("\nAre they the same rows?", deliv_vol_null.index.equals(deliv_pct_null.index))

# Display first few rows where either column is null to verify
print("\nSample rows with null values:")
print(df[df['Deliverable Volume'].isnull() | df['%Deliverble'].isnull()].head())
# Out:
# Number of null values in Deliverable Volume: 517
# Number of null values in %Deliverble: 517
#
# Are they the same rows? True
#
# Sample rows with null values:
#          Date     Symbol Series  Prev Close   Open   High    Low   Last  \
# 0  2000-01-03  ICICIBANK     EQ       69.20  74.35  74.75  71.40  74.75
# 1  2000-01-04  ICICIBANK     EQ       74.75  73.05  78.50  71.00  73.25
# 2  2000-01-05  ICICIBANK     EQ       73.05  70.00  73.50  67.50  70.00
# 3  2000-01-06  ICICIBANK     EQ       69.50  71.00  74.00  69.55  69.75
# 4  2000-01-07  ICICIBANK     EQ       70.05  69.00  72.50  66.00  67.00
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  74.75  73.20  286260  2.095439e+12     NaN                 NaN          NaN
# 1  73.05  73.38  296264  2.173893e+12     NaN                 NaN          NaN
# 2  69.50  70.85  227624  1.612794e+12     NaN                 NaN          NaN
# 3  70.05  72.04  275149  1.982121e+12     NaN                 NaN          NaN
# 4  67.40  68.72  138809  9.538882e+11     NaN                 NaN          NaN

# %%
df["Trades"] = df["Trades"].fillna(df["Trades"].median())

# %%
df.dropna(subset=['Deliverable Volume', '%Deliverble'], inplace= True)
df.isnull().sum()
# Out:
# Date                  0
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
df_tre_mean = df['Trades'].mean()
df_tre_median = df.Trades.median()
df_tre_mode = df.Trades.mode()

# %%
df_tre_mean
# Out:
# np.float64(124597.31175610775)

# %%
df_tre_median
# Out:
# np.float64(110101.0)

# %%
df_tre_mode
# Out:
# 0    110101.0
# Name: Trades, dtype: float64

# %%
df.sample(5)
# Out:
#             Date     Symbol Series  Prev Close     Open     High      Low  \
# 4042  2016-03-21  ICICIBANK     EQ      230.20   231.55   235.60   231.45
# 4508  2018-02-06  ICICIBANK     EQ      329.70   315.25   337.95   313.00
# 3640  2014-07-31  ICICIBANK     EQ     1488.45  1494.75  1505.00  1466.20
# 1015  2004-01-19  ICICIBANK     EQ      283.30   288.00   302.50   284.05
# 2197  2008-10-07  ICICIBANK     EQ      490.05   501.20   521.40   463.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# 4042   235.15   234.85   233.72  13471290  3.148461e+14  124474.0
# 4508   332.00   330.70   325.73  18491736  6.023300e+14  140778.0
# 3640  1471.20  1471.25  1485.22   3968720  5.894440e+14  120518.0
# 1015   300.80   300.10   294.00   2561911  7.532082e+13  110101.0
# 2197   488.10   485.05   489.33  12438534  6.086565e+14  110101.0
#
#       Deliverable Volume  %Deliverble
# 4042           7472056.0       0.5547
# 4508           7968175.0       0.4309
# 3640           2022803.0       0.5097
# 1015           1351514.0       0.5275
# 2197           2377705.0       0.1912

# %%
df['Trades'] = df['Trades'].astype(int)
df['Deliverable Volume'] = df['Deliverable Volume'].astype(int)
df['%Deliverble'] = df['%Deliverble'].astype(float)

# %%
df['turnover_billions'] = df['Turnover']

# %%
df.turnover_billions
# Out:
# 498     4.168734e+11
# 499     6.249913e+11
# 500     1.293277e+12
# 501     8.209558e+11
# 502     1.370891e+12
#             ...
# 5301    3.731429e+15
# 5302    1.448630e+15
# 5303    2.039422e+15
# 5304    2.139792e+15
# 5305    1.435801e+15
# Name: turnover_billions, Length: 4789, dtype: float64

# %%
df.drop('Turnover', axis=1)
# Out:
#             Date     Symbol Series  Prev Close    Open    High     Low  \
# 498   2002-01-01  ICICIBANK     EQ       88.70   89.95   89.95   87.30
# 499   2002-01-02  ICICIBANK     EQ       88.50   88.00   89.00   87.50
# 500   2002-01-03  ICICIBANK     EQ       88.40   86.60   92.95   86.60
# 501   2002-01-04  ICICIBANK     EQ       92.00   92.50   93.20   90.00
# 502   2002-01-07  ICICIBANK     EQ       91.10   91.00   92.50   89.25
# ...          ...        ...    ...         ...     ...     ...     ...
# 5301  2021-04-26  ICICIBANK     EQ      569.95  602.00  605.50  588.00
# 5302  2021-04-27  ICICIBANK     EQ      591.10  593.25  601.95  591.10
# 5303  2021-04-28  ICICIBANK     EQ      598.75  598.00  622.80  598.00
# 5304  2021-04-29  ICICIBANK     EQ      621.35  622.55  628.45  609.00
# 5305  2021-04-30  ICICIBANK     EQ      621.45  610.10  616.35  598.10
#
#         Last   Close    VWAP    Volume  Trades  Deliverable Volume  \
# 498    88.05   88.50   88.53     47087  110101               35559
# 499    87.60   88.40   88.05     70982  110101               64128
# 500    92.05   92.00   90.40    143055  110101              114325
# 501    91.90   91.10   91.43     89792  110101               73659
# 502    91.05   90.15   90.58    151344  110101              123531
# ...      ...     ...     ...       ...     ...                 ...
# 5301  588.70  591.10  596.22  62584522  546696            16913351
# 5302  599.00  598.75  597.63  24239685  233412             9056247
# 5303  619.70  621.35  612.57  33292864  295406            14011476
# 5304  621.00  621.45  619.55  34537860  304029            10324897
# 5305  599.70  600.50  607.02  23653258  247055             7292392
#
#       %Deliverble  turnover_billions
# 498        0.7552       4.168734e+11
# 499        0.9034       6.249913e+11
# 500        0.7992       1.293277e+12
# 501        0.8203       8.209558e+11
# 502        0.8162       1.370891e+12
# ...           ...                ...
# 5301       0.2702       3.731429e+15
# 5302       0.3736       1.448630e+15
# 5303       0.4209       2.039422e+15
# 5304       0.2989       2.139792e+15
# 5305       0.3083       1.435801e+15
#
# [4789 rows x 15 columns]

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4789.000000  4789.000000  4789.000000  4789.000000  4789.000000
# mean    593.833692   594.477668   604.036490   583.926373   593.989570
# std     362.696694   362.836284   367.988997   357.301566   362.609018
# min      88.400000    86.600000    89.000000    85.950000    87.600000
# 25%     293.250000   294.150000   298.500000   290.000000   293.650000
# 50%     471.250000   474.000000   481.500000   462.250000   470.650000
# 75%     898.950000   899.000000   912.550000   884.000000   899.000000
# max    1794.100000  1767.050000  1798.150000  1760.150000  1793.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  4789.000000  4789.000000  4.789000e+03  4.789000e+03    4789.000000
# mean    593.939946   594.088985  9.089822e+06  4.161676e+14  124597.311756
# std     362.623906   362.632303  1.252289e+07  4.840887e+14   72290.478297
# min      88.400000    87.970000  2.446900e+04  2.222625e+11    2595.000000
# 25%     293.500000   293.450000  1.609008e+06  9.231696e+13  108315.000000
# 50%     471.850000   471.790000  4.162607e+06  3.243029e+14  110101.000000
# 75%     898.950000   899.040000  1.254406e+07  5.305852e+14  111329.000000
# max    1794.100000  1783.460000  2.868577e+08  1.461959e+16  949891.000000
#
#        Deliverable Volume  %Deliverble  turnover_billions
# count        4.789000e+03  4789.000000       4.789000e+03
# mean         4.183406e+06     0.473463       4.161676e+14
# std          6.365382e+06     0.131495       4.840887e+14
# min          1.501500e+04     0.099000       2.222625e+11
# 25%          6.995020e+05     0.384300       9.231696e+13
# 50%          1.963117e+06     0.476400       3.243029e+14
# 75%          5.948817e+06     0.564100       5.305852e+14
# max          2.325307e+08     0.983000       1.461959e+16

# %% [markdown]
# **DATA VIZUALISATION**

# %%
df['Date']=pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df
# Out:
#                Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2002-01-01  ICICIBANK     EQ       88.70   89.95   89.95   87.30   88.05
# 2002-01-02  ICICIBANK     EQ       88.50   88.00   89.00   87.50   87.60
# 2002-01-03  ICICIBANK     EQ       88.40   86.60   92.95   86.60   92.05
# 2002-01-04  ICICIBANK     EQ       92.00   92.50   93.20   90.00   91.90
# 2002-01-07  ICICIBANK     EQ       91.10   91.00   92.50   89.25   91.05
# ...               ...    ...         ...     ...     ...     ...     ...
# 2021-04-26  ICICIBANK     EQ      569.95  602.00  605.50  588.00  588.70
# 2021-04-27  ICICIBANK     EQ      591.10  593.25  601.95  591.10  599.00
# 2021-04-28  ICICIBANK     EQ      598.75  598.00  622.80  598.00  619.70
# 2021-04-29  ICICIBANK     EQ      621.35  622.55  628.45  609.00  621.00
# 2021-04-30  ICICIBANK     EQ      621.45  610.10  616.35  598.10  599.70
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2002-01-01   88.50   88.53     47087  4.168734e+11  110101
# 2002-01-02   88.40   88.05     70982  6.249913e+11  110101
# 2002-01-03   92.00   90.40    143055  1.293277e+12  110101
# 2002-01-04   91.10   91.43     89792  8.209558e+11  110101
# 2002-01-07   90.15   90.58    151344  1.370891e+12  110101
# ...            ...     ...       ...           ...     ...
# 2021-04-26  591.10  596.22  62584522  3.731429e+15  546696
# 2021-04-27  598.75  597.63  24239685  1.448630e+15  233412
# 2021-04-28  621.35  612.57  33292864  2.039422e+15  295406
# 2021-04-29  621.45  619.55  34537860  2.139792e+15  304029
# 2021-04-30  600.50  607.02  23653258  1.435801e+15  247055
#
#             Deliverable Volume  %Deliverble  turnover_billions
# Date
# 2002-01-01               35559       0.7552       4.168734e+11
# 2002-01-02               64128       0.9034       6.249913e+11
# 2002-01-03              114325       0.7992       1.293277e+12
# 2002-01-04               73659       0.8203       8.209558e+11
# 2002-01-07              123531       0.8162       1.370891e+12
# ...                        ...          ...                ...
# 2021-04-26            16913351       0.2702       3.731429e+15
# 2021-04-27             9056247       0.3736       1.448630e+15
# 2021-04-28            14011476       0.4209       2.039422e+15
# 2021-04-29            10324897       0.2989       2.139792e+15
# 2021-04-30             7292392       0.3083       1.435801e+15
#
# [4789 rows x 15 columns]

# %%
plt.figure(figsize=(12,5))
plt.plot(df['VWAP'], label="VWAP", color='blue')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock VWAP Price Trend')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(df['Volume'], label="vol", color='blue')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Volume Trend')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(df['Trades'], label="Trades", color='blue')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Trades Trend')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Close'], bins=50, kde=True)
plt.title('closing prices distribution')
# Out:
# Text(0.5, 1.0, 'closing prices distribution')

# %%
df['SMA_20'] = df['Close'].rolling(window=20).mean()
df['SMA_50'] = df['Close'].rolling(window=50).mean()
df['SMA_100'] = df['Close'].rolling(window=100).mean()

# Plot moving averages
plt.figure(figsize=(12,6))
plt.plot(df['Close'], label="Closing Price", color='blue')
plt.plot(df['SMA_20'], label="20-Day SMA", color='green')
plt.plot(df['SMA_50'], label="50-Day SMA", color='red')
plt.plot(df['SMA_100'], label="100-Day SMA", color='orange')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Price with Moving Averages')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df['Close'])
plt.title('Box Plot of Closing Prices')
plt.show()

# %%
df
# Out:
#                Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2002-01-01  ICICIBANK     EQ       88.70   89.95   89.95   87.30   88.05
# 2002-01-02  ICICIBANK     EQ       88.50   88.00   89.00   87.50   87.60
# 2002-01-03  ICICIBANK     EQ       88.40   86.60   92.95   86.60   92.05
# 2002-01-04  ICICIBANK     EQ       92.00   92.50   93.20   90.00   91.90
# 2002-01-07  ICICIBANK     EQ       91.10   91.00   92.50   89.25   91.05
# ...               ...    ...         ...     ...     ...     ...     ...
# 2021-04-26  ICICIBANK     EQ      569.95  602.00  605.50  588.00  588.70
# 2021-04-27  ICICIBANK     EQ      591.10  593.25  601.95  591.10  599.00
# 2021-04-28  ICICIBANK     EQ      598.75  598.00  622.80  598.00  619.70
# 2021-04-29  ICICIBANK     EQ      621.35  622.55  628.45  609.00  621.00
# 2021-04-30  ICICIBANK     EQ      621.45  610.10  616.35  598.10  599.70
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2002-01-01   88.50   88.53     47087  4.168734e+11  110101
# 2002-01-02   88.40   88.05     70982  6.249913e+11  110101
# 2002-01-03   92.00   90.40    143055  1.293277e+12  110101
# 2002-01-04   91.10   91.43     89792  8.209558e+11  110101
# 2002-01-07   90.15   90.58    151344  1.370891e+12  110101
# ...            ...     ...       ...           ...     ...
# 2021-04-26  591.10  596.22  62584522  3.731429e+15  546696
# 2021-04-27  598.75  597.63  24239685  1.448630e+15  233412
# 2021-04-28  621.35  612.57  33292864  2.039422e+15  295406
# 2021-04-29  621.45  619.55  34537860  2.139792e+15  304029
# 2021-04-30  600.50  607.02  23653258  1.435801e+15  247055
#
#             Deliverable Volume  %Deliverble  turnover_billions    SMA_20  \
# Date
# 2002-01-01               35559       0.7552       4.168734e+11       NaN
# 2002-01-02               64128       0.9034       6.249913e+11       NaN
# 2002-01-03              114325       0.7992       1.293277e+12       NaN
# 2002-01-04               73659       0.8203       8.209558e+11       NaN
# 2002-01-07              123531       0.8162       1.370891e+12       NaN
# ...                        ...          ...                ...       ...
# 2021-04-26            16913351       0.2702       3.731429e+15  572.1825
# 2021-04-27             9056247       0.3736       1.448630e+15  573.7450
# 2021-04-28            14011476       0.4209       2.039422e+15  576.2350
# 2021-04-29            10324897       0.2989       2.139792e+15  578.3800
# 2021-04-30             7292392       0.3083       1.435801e+15  578.8325
#
#              SMA_50   SMA_100
# Date
# 2002-01-01      NaN       NaN
# 2002-01-02      NaN       NaN
# 2002-01-03      NaN       NaN
# 2002-01-04      NaN       NaN
# 2002-01-07      NaN       NaN
# ...             ...       ...
# 2021-04-26  600.091  566.9400
# 2021-04-27  599.399  568.1745
# 2021-04-28  599.183  569.6545
# 2021-04-29  598.999  571.0180
# 2021-04-30  598.057  572.2185
#
# [4789 rows x 18 columns]

# %%
highest_high = df['High'].max()
lowest_low = df['Low'].min()

# %%
print("highest high:", highest_high)
print("lowest low:", lowest_low)
# Out:
# highest high: 1798.15
# lowest low: 85.95

# %%
highest_high_date = df[df['High'] == highest_high].index[0]
lowest_low_date = df[df['Low'] == lowest_low].index[0]
time_diff = abs(highest_high_date - lowest_low_date)

# %%
print('highest high date:', highest_high_date)
print('lowest_low_date:', lowest_low)
print('time difference:', time_diff)
# Out:
# highest high date: 2014-12-03 00:00:00
# lowest_low_date: 85.95
# time difference: 4690 days 00:00:00

# %%
plt.figure(figsize=(12,6))

# Calculate rolling average for smoothing (30 day window)
rolling_avg = df['turnover_billions'].rolling(window=30).mean()

# Plot original turnover as light line
plt.plot(df.index, df['turnover_billions'], color='lightblue', alpha=0.3, label='Original Turnover')

# Plot smoothed turnover line
plt.plot(df.index, rolling_avg, color='blue', linewidth=2, label='30-Day Moving Average')

# Customize the plot
plt.title('Smoothed Turnover Over Time')
plt.xlabel('Date')
plt.ylabel('Turnover (Billions)')

# Add legend
plt.legend(loc='upper left')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>

# %%
# Calculate daily VWAP changes
df['VWAP_Change'] = df['VWAP'].pct_change()

# Define what constitutes an upward pattern (e.g. consecutive days of increase)
consecutive_days = 3  # Looking for 3 consecutive days of increase
threshold = 0.01  # 1% minimum increase per day

# Find dates where VWAP increased consecutively
upward_patterns = []
for i in range(consecutive_days, len(df)):
    # Check if we have consecutive days of increase above threshold
    is_pattern = True
    for j in range(consecutive_days):
        if df['VWAP_Change'].iloc[i-j] < threshold:
            is_pattern = False
            break
    if is_pattern:
        upward_patterns.append(df.index[i])

print(f"\nFound {len(upward_patterns)} instances of {consecutive_days} consecutive days")
print(f"where VWAP increased by at least {threshold*100}% each day\n")
